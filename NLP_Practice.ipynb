# %% [markdown]
# <a href="https://colab.research.google.com/github/HitenKumar786/NLP-Task-Practice/blob/main/NLP_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing Libraries

import tensorflow  as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.datasets import imdb
import numpy as np

# %%
#Load Dataset

(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words=10000)

# %%
# Data Processing - Tokenizing and Padding

max_len = 100
x_train = pad_sequences(x_train,maxlen=max_len)
x_test = pad_sequences(x_test,maxlen=max_len)

print('Training Data Shape:',x_train.shape)
print('Testing Data Shape:',x_test.shape)
# Out:
# Training Data Shape: (25000, 100)
# Testing Data Shape: (25000, 100)

# %%
model = Sequential([Embedding(input_dim=10000,output_dim=128,input_length=max_len),
          Flatten(),
          Dense(32,activation = 'relu'),
          Dense(1,activation = 'sigmoid')
          ])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9960 - loss: 0.0137 - val_accuracy: 0.8248 - val_loss: 0.6734
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.8068 - val_loss: 0.8614
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9999 - loss: 9.6987e-04 - val_accuracy: 0.8250 - val_loss: 0.8032
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 1.0000 - loss: 1.2669e-04 - val_accuracy: 0.8256 - val_loss: 0.8307
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 1.0000 - loss: 5.1268e-05 - val_accuracy: 0.8270 - val_loss: 0.8528
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 1.0000 - loss: 3.0350e-05 - val_accuracy: 0.8276 - val_loss: 0.8735
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 1.0000 - loss: 1.9149e-05 - val_accuracy: 0.8284 - val_loss: 0.8937
# Epoch 8/10
# ...

# %%
loss,accuracy = model.evaluate(x_test,y_test)
print('Loss:',loss)
print('Accuracy:',accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8297 - loss: 0.9543
# Loss: 0.9543436765670776
# Accuracy: 0.8297200202941895

# %%
from google.colab import drive
drive.mount('/content/drive')
